# %% [markdown]
# <i> From lecture of Professor Sanjiv Das - Santa Clara University

# %%
# %pylab inline
import pandas as pd
from ipypublish import nb_setup
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 1. What is SVM?

# %% [markdown]
# <li> Supervised learning models
# <li> Learning algorithms used for classification and regression analysis.

# %% [markdown]
# ## 2. SVM Algorithms - the math behind
